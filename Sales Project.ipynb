# %% [markdown]
# ### Business Requirement:
# We have SuperStore Sample retail data and our stakeholder wants to track the below business metrics.

# %%
dbutils.widgets.dropdown("Time_Period","Weekly",["Weekly", "Monthly"])

# %%
from datetime import date, datetime, timedelta
from pyspark.sql.functions import *

TimePeriod = dbutils.widgets.get("Time_Period")
print(TimePeriod)
today = date.today()

# Last week start date and end date
if TimePeriod == "Weekly":
    start_date = today - timedelta(days=today.weekday(), weeks=1) - timedelta(days=1)
    end_date = start_date + timedelta(days=6)

# Last month start date and end date
else:
    end_date = today.replace(day=1) - timedelta(days=1)
    start_date = today.replace(day=1) - timedelta(days=end_date.day)

print(start_date, end_date)
# Out:
# Weekly
# 2025-07-13 2025-07-19

# %%
df=spark.read.option("header",True).option("inferSchema", True).csv("/FileStore/tables/superstore.csv")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>Order_ID</th><th>Order_Date</th><th>Ship_Date</th><th>Ship_Mode</th><th>Customer_ID</th><th>Customer_Name</th><th>Segment</th><th>Country</th><th>City</th><th>State</th><th>Postal_Code</th><th>Region</th><th>Product_ID</th><th>Category</th><th>Sub_Category</th><th>Product</th><th>Sales</th><th>Quantity</th><th>Discount</th><th>Profit</th><th>User_ID</th><th>State_ID</th><th>Order_Status</th></tr></thead><tbody><tr><td>1</td><td>ORD-2D0139AA</td><td>2025-07-31</td><td>2025-08-05</td><td>Second Class</td><td>CUST-0FECF7</td><td>Brian Yang</td><td>Home Office</td><td>India</td><td>North Judithbury</td><td>South Dakota</td><td>29757</td><td>East</td><td>PROD-E0B9C6C7</td><td>Furniture</td><td>Tables</td><td>Tables Begin</td><td>739.11</td><td>9</td><td>0.0</td><td>146.07</td><td>USER-1520</td><td>STATE-130</td><td>Completed</td></tr><tr><td>2</td><td>ORD-CAC6E9CC</td><td>2025-10-06</td><td>2025-10-16</td><td>First Class</td><td>CUST-4D611C</td><td>Lance Hoffman</td><td>Home Office</td><td>Germany</td><td>Johnsonland</td><td>Pennsylvania</td><td>29158</td><td>West</td><td>PROD-AACA948E</td><td>Technology</td><td>Accessories</td><td>Accessories Rate</td><td>718.86</td><td>9</td><td>0.3</td><td>52.89</td><td>USER-5557</td><td>STATE-928</td><td>Completed</td></tr><tr><td>3</td><td>ORD-B4961EF7</td><td>2025-09-29</td><td>2025-10-04</td><td>Second Class</td><td>CUST-022189</td><td>Abigail Shaffer</td><td>Corporate</td><td>United Kingdom</td><td>Robinsonshire</td><td>Vermont</td><td>36964</td><td>South</td><td>PROD-9C79DEF9</td><td>Furniture</td><td>Bookcases</td><td>Bookcases Knowledge</td><td>111.19</td><td>7</td><td>0.0</td><td>15.54</td><td>USER-6635</td><td>STATE-718</td><td>Cancelled</td></tr><tr><td>4</td><td>ORD-8351C7AD</td><td>2025-08-23</td><td>2025-08-25</td><td>Same Day</td><td>CUST-8248CE</td><td>Brent Abbott</td><td>Home Office</td><td>United States</td><td>Ericmouth</td><td>Michigan</td><td>13897</td><td>South</td><td>PROD-D1EB51DD</td><td>Furniture</td><td>Bookcases</td><td>Bookcases Everything</td><td>831.11</td><td>10</td><td>0.2</td><td>129.21</td><td>USER-2139</td><td>STATE-146</td><td>Pending</td></tr><tr><td>5</td><td>ORD-6AA69AE0</td><td>2025-12-01</td><td>2025-12-03</td><td>Same Day</td><td>CUST-14BB99</td><td>Sandra Montgomery</td><td>Consumer</td><td>Canada</td><td>Herrerafurt</td><td>Arizona</td><td>10829</td><td>East</td><td>PROD-9BAB7F31</td><td>Office Supplies</td><td>Labels</td><td>Labels High</td><td>639.33</td><td>6</td><td>0.1</td><td>82.02</td><td>USER-4432</td><td>STATE-786</td><td>Cancelled</td></tr><tr><td>6</td><td>ORD-FDD3EAB9</td><td>2025-04-01</td><td>2025-04-05</td><td>Second Class</td><td>CUST-724300</td><td>Dylan Miller</td><td>Home Office</td><td>India</td><td>Lake Chad</td><td>Oregon</td><td>87174</td><td>West</td><td>PROD-A9048D61</td><td>Office Supplies</td><td>Labels</td><td>Labels Trial</td><td>277.25</td><td>9</td><td>0.1</td><td>55.18</td><td>USER-1916</td><td>STATE-334</td><td>Completed</td></tr><tr><td>7</td><td>ORD-C707ACFA</td><td>2025-09-23</td><td>2025-09-25</td><td>Second Class</td><td>CUST-A30667</td><td>Daniel Adams</td><td>Corporate</td><td>Australia</td><td>Ramirezstad</td><td>Connecticut</td><td>21820</td><td>South</td><td>PROD-D12BF617</td><td>Technology</td><td>Copiers</td><td>Copiers Raise</td><td>220.5</td><td>8</td><td>0.3</td><td>41.86</td><td>USER-8517</td><td>STATE-246</td><td>Cancelled</td></tr><tr><td>8</td><td>ORD-4EF71C4B</td><td>2025-09-25</td><td>2025-10-04</td><td>Standard Class</td><td>CUST-1FDA41</td><td>Devin Schaefer</td><td>Home Office</td><td>United Kingdom</td><td>New Jessica</td><td>California</td><td>21918</td><td>West</td><td>PROD-9EF2C53D</td><td>Technology</td><td>Machines</td><td>Machines Onto</td><td>898.84</td><td>7</td><td>0.2</td><td>75.38</td><td>USER-3266</td><td>STATE-621</td><td>Processing</td></tr><tr><td>9</ ...

# %%
df.createOrReplaceTempView("SuperStore")

# %% [markdown]
# ### 1. How many total number of customers we have?

# %%
# %sql
SELECT COUNT(DISTINCT Customer_ID) FROM SuperStore
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCT Customer_ID)</th></tr></thead><tbody><tr><td>1000</td></tr></tbody></table></div>

# %%
display(spark.sql(f"""
            SELECT COUNT(DISTINCT Customer_ID)
            FROM SuperStore
            WHERE ORDER_DATE BETWEEN '{start_date}' AND '{end_date}'"""))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCT Customer_ID)</th></tr></thead><tbody><tr><td>21</td></tr></tbody></table></div>

# %% [markdown]
# ### 2.What is the total number of orders we have?

# %%
# %sql
SELECT COUNT(DISTINCT Order_ID) FROM SuperStore
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCT Order_ID)</th></tr></thead><tbody><tr><td>1000</td></tr></tbody></table></div>

# %%
display(spark.sql(f"""
            SELECT COUNT(DISTINCT Order_ID)
            FROM SuperStore
            WHERE ORDER_DATE BETWEEN '{start_date}' AND '{end_date}'"""))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCT Order_ID)</th></tr></thead><tbody><tr><td>21</td></tr></tbody></table></div>

# %% [markdown]
# ### Total Number of Sales and Profit

# %%
# %sql
SELECT SUM(Sales), SUM(Profit)
FROM SuperStore
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sum(Sales)</th><th>sum(Profit)</th></tr></thead><tbody><tr><td>492157.0299999993</td><td>73407.59000000014</td></tr></tbody></table></div>

# %%
# %sql
SELECT Country, ROUND(SUM(Sales),2) AS Total_Sales
FROM SuperStore
GROUP By Country
ORDER By Total_Sales
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Category</th><th>Total_Sales</th></tr></thead><tbody><tr><td>Office Supplies</td><td>175267.08</td></tr><tr><td>Technology</td><td>158774.57</td></tr><tr><td>Furniture</td><td>158115.38</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
SELECT Category, Sub_Category, ROUND(SUM(Sales),2) AS Total_Sales
FROM SuperStore
GROUP BY 1,2
ORDER BY 3 DESC
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Category</th><th>Sub_Category</th><th>Total_Sales</th></tr></thead><tbody><tr><td>Office Supplies</td><td>Labels</td><td>46200.48</td></tr><tr><td>Office Supplies</td><td>Art</td><td>45668.0</td></tr><tr><td>Technology</td><td>Copiers</td><td>44883.63</td></tr><tr><td>Technology</td><td>Accessories</td><td>44025.8</td></tr><tr><td>Office Supplies</td><td>Paper</td><td>42033.61</td></tr><tr><td>Furniture</td><td>Bookcases</td><td>41625.98</td></tr><tr><td>Office Supplies</td><td>Binders</td><td>41364.99</td></tr><tr><td>Furniture</td><td>Tables</td><td>40255.82</td></tr><tr><td>Furniture</td><td>Chairs</td><td>38521.31</td></tr><tr><td>Furniture</td><td>Furnishings</td><td>37712.27</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ### Most Ordered Products

# %%
# %sql
-- SELECT Product, SUM(Quantity) AS Total_Quantity
-- FROM SuperStore
-- GROUP By 1
-- ORDER By 2 DESC

SELECT
  Total_Quantity,
  ARRAY_AGG(Product) AS Products  --- can also use collect_set()
FROM (
  SELECT Product, SUM(Quantity) AS Total_Quantity
  FROM SuperStore
  GROUP BY Product
) sub
GROUP BY Total_Quantity
ORDER BY Total_Quantity DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Total_Quantity</th><th>Products</th></tr></thead><tbody><tr><td>21</td><td>List(Copiers Raise)</td></tr><tr><td>20</td><td>List(Machines I)</td></tr><tr><td>18</td><td>List(Paper Computer)</td></tr><tr><td>17</td><td>List(Furnishings Eye, Furnishings Available, Copiers Dinner, Phones School)</td></tr><tr><td>16</td><td>List(Machines Us)</td></tr><tr><td>15</td><td>List(Labels High, Furnishings Hand, Accessories Live)</td></tr><tr><td>14</td><td>List(Bookcases Build, Chairs Shoulder)</td></tr><tr><td>13</td><td>List(Phones Agree, Bookcases Open)</td></tr><tr><td>12</td><td>List(Binders Consumer, Bookcases Impact, Binders Fast, Paper Realize, Art Cell)</td></tr><tr><td>11</td><td>List(Art Might, Phones Land)</td></tr><tr><td>10</td><td>List(Chairs Find, Binders Popular, Chairs Arrive, Art Base, Tables Spring, Bookcases Everything, Binders Price, Art Allow, Copiers Radio, Tables Training, Furnishings Example, Chairs Hope, Paper Represent, Tables Pattern, Tables Expect, Tables Position, Binders Crime, Machines Every, Labels Give, Art Increase, Paper Game, Paper President, Accessories Fire, Binders Western, Accessories Million, Bookcases Science, Copiers Check, Art Team, Binders Program, Chairs Significant, Bookcases Hear, Paper Alone, Bookcases Former, Phones Her, Binders Force, Accessories Stand, Art Until, Art Religious, Chairs Security, Accessories Strong, Accessories By, Art Firm, Art Admit, Accessories Short, Phones We, Copiers Animal, Copiers Believe, Copiers Enough, Art White, Art So, Copiers Cover, Chairs Who, Tables Power, Chairs Ok, Copiers Skin, Chairs Billion, Copiers Form, Chairs Cover, Chairs Market, Bookcases Break, Binders Summer, Accessories Record, Binders Onto, Copiers Particular, Accessories Country, Labels Responsibility, Labels Out, Paper Conference, Bookcases Question, Copiers Score, Phones According, Phones Model, Copiers Play, Furnishings Read, Chairs Way, Chairs Know, Art Former, Copiers According, Labels Buy, Accessories Music, Art Whether, Phones Opportunity, Phones Special, Machines Common, Labels Because, Binders See, Phones Institution, Chairs Sound, Binders Behavior, Art Record, Accessories Material, Phones Expert, Copiers Shoulder, Copiers Well, Binders Amount, Binders Through, Paper Her, Machines Industry, Tables Mission, Phones System, Machines Father, Copiers Popular, Bookcases Include)</td></tr><tr><td>9</td><td>List(Phones Think, Tables Southern, Copiers Sometimes, Chairs Test, Machines Coach, Machines Card, Labels Push, Machines Put, Art Attack, Labels Drug, Furnishings Save, Accessories Rate, Bookcases Fire, Copiers Seven, Chairs Order, Labels Defense, Binders Organization, Art Answer, Machines Arrive, Copiers Election, Tables Cup, Binders Little, Copiers Community, Labels Thing, Machines Model, Labels Contain, Labels Agree, Copiers Create, Labels Along, Furnishings Avoid, Binders School, Binders No, Tables Item, Labels Trial, Labels Young, Paper Challenge, Labels Check, Binders Letter, Paper Trouble, Art Democrat, Copiers Middle, Binders Factor, Tables Appear, Art Professional, Phones Reveal, Bookcases Campaign, Paper Story, Copiers Bar, Copiers Pick, Chairs Some, Binders Daughter, Phones Knowledge, Accessories Senior, Art Child, Furnishings Ever, Labels Hear, Labels Act, Furnishings Stand, Phones Range, Accessories Yard, Labels They, Furnishings Blood, Chairs Occur, Bookcases Base, Paper Physical, Phones Door, Copiers Floor, Tables Contain, Bookcases Number, Accessories Decide, Chairs Friend, Bookcases Of, Furnishings Answer, Binders Floor, Chairs Window, Tables Shoulder, Furnishings Line, Labels Green, Bookcases President, Art Meeting, Labels Bad, Tables Know, Machines Number, Furnishings Site, Paper Type, Tables Begin, Copiers Personal, Furnishings Find, Bookcases About, Copiers Now, Binders High, Machines Success, Paper Member, Accessories Seat, Chairs Kind, Binders Air ...
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ### TOP Customers based on Sales and City

# %%
# %sql
SELECT Customer_ID, CUstomer_Name, City, SUM(Sales) AS Total_Sales
FROM SUperStore
GROUP BY Customer_ID, CUstomer_Name, City
ORDER BY Total_Sales DESC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Customer_ID</th><th>CUstomer_Name</th><th>City</th><th>Total_Sales</th></tr></thead><tbody><tr><td>CUST-032848</td><td>Gregg Weaver</td><td>Port Heather</td><td>997.98</td></tr><tr><td>CUST-D6A006</td><td>Mary Miller</td><td>New Amanda</td><td>996.98</td></tr><tr><td>CUST-0F1EC6</td><td>Jessica Fowler</td><td>West Kevinberg</td><td>995.61</td></tr><tr><td>CUST-235DF4</td><td>Melissa Rodriguez</td><td>Michelleton</td><td>995.41</td></tr><tr><td>CUST-990AD3</td><td>Veronica Silva</td><td>Cabrerastad</td><td>992.56</td></tr><tr><td>CUST-36EEF7</td><td>Joseph Johnson</td><td>Kimberlybury</td><td>992.47</td></tr><tr><td>CUST-E95393</td><td>Matthew Fox</td><td>Lake Devinborough</td><td>991.92</td></tr><tr><td>CUST-D96984</td><td>Joseph Blankenship</td><td>East Nicholasberg</td><td>991.36</td></tr><tr><td>CUST-DE3DF3</td><td>Laura Mckinney</td><td>South Andrewland</td><td>990.71</td></tr><tr><td>CUST-40C4E4</td><td>Elizabeth Morrison</td><td>Manuelland</td><td>990.33</td></tr><tr><td>CUST-C9C837</td><td>Matthew Ramirez</td><td>Alexanderborough</